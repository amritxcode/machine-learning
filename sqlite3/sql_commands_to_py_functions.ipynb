# %% [markdown]
# <a href="https://colab.research.google.com/github/amritxcode/machine-learning/blob/main/sqlite3/sql_commands_to_py_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

conn = sqlite3.connect('inventory.db')
cursor = conn.cursor()

cursor.execute ('''
create table if not exists inventory (
item_id integer primary key,
item_name text unique,
quantity integer,
price real
)
''')
conn.commit()

# %%
def add_item(name, quantity, price):
  try:
    cursor.execute(
        "insert or ignore into inventory (item_name,quantity, price) values (?,?,?)",
        (name, quantity, price)
    )
    conn.commit()
    print(f"Successfully added: {name}")
  except Exception as e:
    print(f"Error: {e}")

add_item('Salt', 10, 25.0)
# Out:
# Successfully added: Salt

# %%
cursor.execute("select * from inventory")
print(cursor.fetchall())
# Out:
# [(1, 'Salt', 10, 25.0)]

# %%
def get_all_items():
  cursor.execute("select * from inventory")
  for row in cursor.fetchall():
    print(row)

def update_price(item_name, new_price):
  try:
    cursor.execute("update inventory set price = ? where item_name =?", (new_price, item_name))
    conn.commit()
    print(f"Successfully updated price for {item_name}")
  except sqlite3.Error as e:
    print(f"Database error: {e}")
def delete_item(item_name):
  try:
    cursor.execute("delete from inventory where item_name =?", (item_name,))
    conn.commit()
    print(f"Successfully deleted {item_name}")
  except sqlite3.Error as e:
    print(f'Database error {e}')
def add_item(item_name, quantity, price):
  cursor.execute("insert or ignore into inventory (item_name, quantity, price) values (?,?,?)", (item_name, quantity, price))
  conn.commit()

# %%
get_all_items()
# Out:
# (1, 'Salt', 10, 25.0)

# %%
update_price('Salt', 25)
# Out:
# Successfully updated price for Salt

# %%
delete_item("Salt")
# Out:
# Successfully deleted Salt

# %%
add_item('sugar', 10, 500)
# Out:
# Successfully added: sugar

# %%
get_all_items()
# Out:
# (1, 'Salt', 10, 25.0)
# (2, 'sugar', 10, 500.0)
