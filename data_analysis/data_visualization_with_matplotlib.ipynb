# %% [markdown]
# <a href="https://colab.research.google.com/github/amritxcode/machine-learning/blob/main/data_analysis/data_visualization_with_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# The Structure always remain in same pattern
# figure -> plot -> label -> show
# plt.figure(figsize=(10,6))
# plt.plot(x,y)
# plt.title('Matplotlib')
# plt.xlabel('X axis')
# plt.yaxis('Y axis')
# plt.show()

# %%
## 6 plots to know
# 1. Line Plot - trends over time
plt.figure(figsize=(10,6))
plt.plot([1,2,3,4,5], [2,4,6,8,10])
plt.title('Line Plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
# 2. Scatter Plot - relationship between two variables
plt.figure(figsize=(10,6))
plt.scatter(df['Age'], df['Fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# 3. Bar Plot - comparing categories
plt.figure(figsize=(10,6))
plt.bar(df['Pclass'].values_counts().index, df['Pclass'].value_counts)
plt.title('Passenger per Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
# 4. Histogram - distribution of one variable
plt.figure(figsize =(10,6))
plt.hist(df['age'].dropna(), bins = 30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
from decorator import DEF
# 5. Multiple Plots on one figure
fig, axes = plt.subplots(1,2, figsize=(12,5))
axes[0].hist(df['Age'].dropna(), bins = 30)
axes[0].set_title('Age Distribution')
axes[1].scatter(df['Age'], df['Fare'])
axes[1].set_title('Age vs Fare')
plt.tight_layout()
plt.show()

# %%
# 6. Save a plot
plt.savefig('myplot.pnd', dpi = 300, bbox_inches='tight')
