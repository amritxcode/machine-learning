# %% [markdown]
# <a href="https://colab.research.google.com/github/amritxcode/machine-learning/blob/main/Multithreading_and_multiprocessing/threading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Code: Threading
import threading

def download_file(filename):
  print(f'Downloading {filename}')
  import time
  time.sleep(2)
  print(f'Done: {filename}')

threads = []
for filename in ["file1.txt", "file2.txt", "file3.txt"]:
  t = threading.Thread(target = download_file, args = (filename,))
  threads.append(t)
  t.start()

for t in threads:
  t.join()

print('All downloads complete')
# Out:
# ...
# Done: file1.txt
# Done: file2.txt
# Done: file3.txt
# All downloads complete
