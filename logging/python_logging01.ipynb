# %% [markdown]
# <a href="https://colab.research.google.com/github/amritxcode/machine-learning/blob/main/logging/python_logging01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import logging
# Setup once
logging.basicConfig(
level = logging.DEBUG,
format = '%(asctime)s - %(levelname)s - %(message)s',
handlers = [
    logging.FileHandler('app.log'),
    logging.StreamHandler()
    ],
      force = True
)

# %%
logging.debug('Checking variable value')
logging.info('Progress started successfully')
logging.warning('Warning message')
logging.error('Error message')
logging.critical('Critical message')
# Out:
# 2026-09-12 05:05:01,237 - DEBUG - Checking variable value
# 2026-09-12 05:05:01,242 - INFO - Progress started successfully
# 2026-09-12 05:05:01,244 - WARNING - Warning message
# 2026-09-12 05:05:01,248 - ERROR - Error message
# 2026-09-12 05:05:01,249 - CRITICAL - Critical message

# %%
with open('app.log', 'r') as f:
  print(f.read())
# Out:
# 2026-09-12 05:05:01,237 - DEBUG - Checking variable value
# 2026-09-12 05:05:01,242 - INFO - Progress started successfully
# 2026-09-12 05:05:01,244 - WARNING - Warning message
# 2026-09-12 05:05:01,248 - ERROR - Error message
# 2026-09-12 05:05:01,249 - CRITICAL - Critical message
